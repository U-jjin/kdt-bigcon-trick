# %%
# 한글 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import math

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# # 1. 데이터 수집
# 빅콘테스트 제공파일

# %%
df0 = pd.read_csv('/content/drive/MyDrive/21 세미프로젝트_2차/원본데이터/01_제공데이터_update(210811)/02-3_단기체류 외국인 유동인구_SHORT_TERM_FRGN.CSV', encoding='cp949')
df0
# Out:
#           base_date  time nationality  city    emd_cd emd_nm  visit_pop_cnt
# 0        2018-01-01     1         CHN   제주시  50110250    한림읍        66.3170
# 1        2018-01-01     1         ETC   제주시  50110250    한림읍        21.1308
# 2        2018-01-01     1         HKG   제주시  50110250    한림읍         3.6771
# 3        2018-01-01     1         JPN   제주시  50110250    한림읍         5.5962
# 4        2018-01-01     1         USA   제주시  50110250    한림읍         3.9078
# ...             ...   ...         ...   ...       ...    ...            ...
# 6059039  2021-06-30    24         USA  서귀포시  50130610    중문동         9.2120
# 6059040  2021-06-30    24         CHN  서귀포시  50130610    중문동         0.6039
# 6059041  2021-06-30    24         ETC  서귀포시  50130610    중문동        11.5473
# 6059042  2021-06-30    24         CHN  서귀포시  50130620    예래동         0.2013
# 6059043  2021-06-30    24         HKG  서귀포시  50130620    예래동         0.0166
#
# [6059044 rows x 7 columns]

# %% [markdown]
# # 2. 데이터 분포 확인

# %% [markdown]
# ## 3) visit_pop_cnt

# %%
figure = plt.figure(figsize=(40, 32))
plt.rcParams.update({'font.size': 15})
sns.boxplot(x="location", y="visit_pop_cnt", data=df1, showmeans=True,
            meanprops={"marker":"s","markerfacecolor":"black", "markeredgecolor":"black"})

# %% [markdown]
# ### (1) 2018년

# %%
test18 = data1[data1['base_date'].dt.year==2018]
test18 = test18.groupby(['time']).sum()
test18
# Out:
#              emd_cd  visit_pop_cnt  weekend
# time
# 1     4280252619584   3.136414e+06    24259
# 2     4280001687129   3.144621e+06    24264
# 3     4278749247184   3.147335e+06    24255
# 4     4280352982153   3.145563e+06    24243
# 5     4278348648676   3.142920e+06    24221
# 6     4272384711156   3.142866e+06    24179
# 7     4265869780260   3.146713e+06    24139
# 8     4257449393596   3.123354e+06    24065
# 9     4272182606625   3.124430e+06    24175
# 10    4317892685798   3.154437e+06    24372
# 11    4349520344412   3.158312e+06    24522
# 12    4338947155038   3.140486e+06    24497
# 13    4306176662725   3.157991e+06    24293
# 14    4293348517840   3.143792e+06    24281
# 15    4298310862784   3.152091e+06    24313
# 16    4307479671541   3.137300e+06    24305
# 17    4356187809912   3.137019e+06    24561
# 18    4388457489081   3.140642e+06    24739
# 19    4394120423552   3.137860e+06    24791
# 20    4377980461144   3.138965e+06    24679
# 21    4366252782675   3.147156e+06    24597
# 22    4338939131194   3.168990e+06    24455
# 23    4309169754947   3.140302e+06    24317
# 24    4282155933074   3.107746e+06    24148

# %%
test18_2 = df1[df1['base_date'].dt.year==2018]
test18_2 = test18_2.groupby(['time_2']).sum()
test18_2
# Out:
#         visit_pop_cnt  week_date  weekend     year  month    day
# time_2
# 새벽       1.196248e+06      13104     1248  8838840  28584  68856
# 오전       1.271504e+06      13104     1248  8838840  28584  68856
# 오후       1.264990e+06      13104     1248  8838840  28584  68856
# 저녁       1.204489e+06      13104     1248  8838840  28584  68856

# %%
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (16, 8)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.arange(1, 25)
y1 = np.array(test18['visit_pop_cnt'])

x_2 = test18_2.index
y1_2 = np.array(test18_2['visit_pop_cnt'])


# 3. 그래프 그리기
fig = plt.figure()
ax1 = plt.subplot(1,2,1)
ax4 = plt.subplot(1,2,2)

## 1) time 변수
ax1.plot(x, y1, color='green', markersize=7, linewidth=5, alpha=0.7, label='resd')
ax1.set_ylim(0, 8000000)
ax1.set_xlabel('time')
ax1.set_ylabel('pop_cnt')
ax1.tick_params(axis='both', direction='in')

ax1.legend(loc=(0, 0.5), ncol=1)

plt.title('year 2018 visit by time')

## 2)time_2 변수
ax4.plot(x_2, y1_2, color='green', markersize=7, linewidth=5, alpha=0.7, label='resd')
ax4.set_ylim(0, 2000000)
ax4.set_xlabel('time')
ax4.set_ylabel('pop_cnt')
ax4.tick_params(axis='both', direction='in')

ax4.legend(loc=(0, 0.5), ncol=1)


plt.title('year 2018 visit by time')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48317 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50724 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45377 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48317 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50724 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45377 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 3. 데이터 전처리
#
# 1) 시간대 분할
#
# 2) 데이터 분할(resd 변수 기준)
#
# 3) 지역 재분류(6개 구역)
#
# 4) 시간대 변수 생성
#
# 5) 데이터 병합

# %% [markdown]
# ## 1) 시간대 분할
# n_visit_12, n_visit_24 : 6개 지역 기준, max로 그룹화

# %%
cond1 = [
         df0['time'] <= 6,
         (df0['time'] > 6) & (df0['time'] <= 18),
         (df0['time'] > 18) & (df0['time'] <= 24),
]

choice1 = [
           '밤',
           '낮',
           '밤'
]

df0['time_2'] = np.select(cond1, choice1, default='NA')

# %%
df0.columns
# Out:
# Index(['base_date', 'time', 'nationality', 'city', 'emd_cd', 'emd_nm',
#        'resd_pop_cnt', 'work_pop_cnt', 'visit_pop_cnt', 'resd', 'time_2'],
#       dtype='object')

# %%
df1 = df0.groupby(['base_date','time_2','nationality', 'city', 'emd_cd', 'emd_nm', 'resd']).max()
df1
# Out:
#                                                          time  ...  visit_pop_cnt
# base_date  time_2 nationality city emd_cd   emd_nm resd        ...
# 2018-01-01 낮      AUS         서귀포시 50130250 대정읍    제주      15  ...         5.9607
#                                    50130253 남원읍    제주      17  ...         5.9677
#                                    50130259 성산읍    제주      14  ...        11.9213
#                                    50130310 안덕면    그외      16  ...         5.9607
#                                                    제주      18  ...        23.8426
# ...                                                       ...  ...            ...
# 2021-06-30 밤      VNM         제주시  50110670 외도동    제주      24  ...         7.5507
#                                    50110680 이호동    그외      24  ...        22.6522
#                                                    제주      24  ...        22.6522
#                                    50110690 도두동    그외      24  ...        11.3261
#                                                    제주      24  ...        15.1014
#
# [2866918 rows x 4 columns]

# %%
df1 = df1.reset_index()

# %%
df1
# Out:
#           base_date time_2  ... work_pop_cnt visit_pop_cnt
# 0        2018-01-01      낮  ...       0.0000        5.9607
# 1        2018-01-01      낮  ...       0.0000        5.9677
# 2        2018-01-01      낮  ...       0.0000       11.9213
# 3        2018-01-01      낮  ...       0.0000        5.9607
# 4        2018-01-01      낮  ...       8.2220       23.8426
# ...             ...    ...  ...          ...           ...
# 2866913  2021-06-30      밤  ...       3.7754        7.5507
# 2866914  2021-06-30      밤  ...       0.0000       22.6522
# 2866915  2021-06-30      밤  ...       0.0000       22.6522
# 2866916  2021-06-30      밤  ...       0.0000       11.3261
# 2866917  2021-06-30      밤  ...       0.0000       15.1014
#
# [2866918 rows x 11 columns]

# %%
df1 = df1.drop(['time'], axis=1)

# %% [markdown]
# ## 2) 데이터 분할(resd 변수 기준)

# %% [markdown]
# ### * resd=제주

# %%
df_jeju = df1[df1['resd'] == '제주']

# %%
df_jeju = df_jeju.drop(['resd'], axis=1)
df_jeju
# Out:
#           base_date time_2  ... work_pop_cnt visit_pop_cnt
# 0        2018-01-01      낮  ...       0.0000        5.9607
# 1        2018-01-01      낮  ...       0.0000        5.9677
# 2        2018-01-01      낮  ...       0.0000       11.9213
# 4        2018-01-01      낮  ...       8.2220       23.8426
# 5        2018-01-01      낮  ...       0.0000        5.9536
# ...             ...    ...  ...          ...           ...
# 2866909  2021-06-30      밤  ...      26.4275       45.3043
# 2866911  2021-06-30      밤  ...      37.7536       41.5290
# 2866913  2021-06-30      밤  ...       3.7754        7.5507
# 2866915  2021-06-30      밤  ...       0.0000       22.6522
# 2866917  2021-06-30      밤  ...       0.0000       15.1014
#
# [1689732 rows x 9 columns]

# %%
df_jeju2 = df_jeju.groupby(['base_date','time_2', 'city', 'emd_cd', 'emd_nm']).sum()
df_jeju2
# Out:
#                                         resd_pop_cnt  ...  visit_pop_cnt
# base_date  time_2 city emd_cd   emd_nm                ...
# 2018-01-01 낮      서귀포시 50130250 대정읍        1066.0740  ...       270.6256
#                        50130253 남원읍         328.2548  ...       194.9233
#                        50130259 성산읍         565.2860  ...       417.2296
#                        50130310 안덕면         774.4354  ...       320.0297
#                        50130320 표선면         352.3231  ...       112.4051
# ...                                              ...  ...            ...
# 2021-06-30 밤      제주시  50110650 연동         2561.4514  ...       579.1678
#                        50110660 노형동        2017.5754  ...       700.2975
#                        50110670 외도동         188.3524  ...        72.1834
#                        50110680 이호동         150.9372  ...       128.9502
#                        50110690 도두동          77.3760  ...        67.8271
#
# [109818 rows x 3 columns]

# %%
df_jeju2 = df_jeju2.reset_index()
df_jeju2
# Out:
#          base_date time_2  city  ...  resd_pop_cnt work_pop_cnt  visit_pop_cnt
# 0       2018-01-01      낮  서귀포시  ...     1066.0740      13.0664       270.6256
# 1       2018-01-01      낮  서귀포시  ...      328.2548      15.1443       194.9233
# 2       2018-01-01      낮  서귀포시  ...      565.2860      50.8318       417.2296
# 3       2018-01-01      낮  서귀포시  ...      774.4354     163.9979       320.0297
# 4       2018-01-01      낮  서귀포시  ...      352.3231       8.7340       112.4051
# ...            ...    ...   ...  ...           ...          ...            ...
# 109813  2021-06-30      밤   제주시  ...     2561.4514     195.5954       579.1678
# 109814  2021-06-30      밤   제주시  ...     2017.5754     163.1943       700.2975
# 109815  2021-06-30      밤   제주시  ...      188.3524      21.9826        72.1834
# 109816  2021-06-30      밤   제주시  ...      150.9372      23.5358       128.9502
# 109817  2021-06-30      밤   제주시  ...       77.3760      15.7211        67.8271
#
# [109818 rows x 8 columns]

# %% [markdown]
# ### * resd=그외

# %%
df_etc = df1[df1['resd'] == '그외']

# %%
df_etc = df_etc.drop(['resd'], axis=1)
df_etc
# Out:
#           base_date time_2  ... work_pop_cnt visit_pop_cnt
# 3        2018-01-01      낮  ...       0.0000        5.9607
# 9        2018-01-01      낮  ...       8.2025        0.0000
# 12       2018-01-01      낮  ...       0.0000        5.9465
# 18       2018-01-01      낮  ...       0.0000        5.9116
# 21       2018-01-01      낮  ...       0.0000        5.9677
# ...             ...    ...  ...          ...           ...
# 2866908  2021-06-30      밤  ...       0.0000       30.2029
# 2866910  2021-06-30      밤  ...       0.0000       60.4058
# 2866912  2021-06-30      밤  ...       0.0000        7.5507
# 2866914  2021-06-30      밤  ...       0.0000       22.6522
# 2866916  2021-06-30      밤  ...       0.0000       11.3261
#
# [1177186 rows x 9 columns]

# %%
df_etc2 = df_etc.groupby(['base_date','time_2', 'city', 'emd_cd', 'emd_nm']).sum()
df_etc2
# Out:
#                                         resd_pop_cnt  ...  visit_pop_cnt
# base_date  time_2 city emd_cd   emd_nm                ...
# 2018-01-01 낮      서귀포시 50130250 대정읍              0.0  ...       152.2208
#                        50130253 남원읍              0.0  ...       131.6772
#                        50130259 성산읍              0.0  ...       267.4784
#                        50130310 안덕면              0.0  ...       203.9756
#                        50130320 표선면              0.0  ...       123.1803
# ...                                              ...  ...            ...
# 2021-06-30 밤      제주시  50110650 연동               0.0  ...       904.5847
#                        50110660 노형동              0.0  ...       541.0726
#                        50110670 외도동              0.0  ...       108.9141
#                        50110680 이호동              0.0  ...       129.6280
#                        50110690 도두동              0.0  ...        98.5622
#
# [109802 rows x 3 columns]

# %%
df_etc2 = df_etc2.reset_index()
df_etc2
# Out:
#          base_date time_2  city  ...  resd_pop_cnt work_pop_cnt  visit_pop_cnt
# 0       2018-01-01      낮  서귀포시  ...           0.0      35.5750       152.2208
# 1       2018-01-01      낮  서귀포시  ...           0.0      37.1352       131.6772
# 2       2018-01-01      낮  서귀포시  ...           0.0      29.1916       267.4784
# 3       2018-01-01      낮  서귀포시  ...           0.0      23.6567       203.9756
# 4       2018-01-01      낮  서귀포시  ...           0.0      28.3955       123.1803
# ...            ...    ...   ...  ...           ...          ...            ...
# 109797  2021-06-30      밤   제주시  ...           0.0      32.1340       904.5847
# 109798  2021-06-30      밤   제주시  ...           0.0      30.6144       541.0726
# 109799  2021-06-30      밤   제주시  ...           0.0       5.2404       108.9141
# 109800  2021-06-30      밤   제주시  ...           0.0       0.0000       129.6280
# 109801  2021-06-30      밤   제주시  ...           0.0       0.0000        98.5622
#
# [109802 rows x 8 columns]

# %% [markdown]
# ## 3) 지역 재분류(6개 구역)
# region : 6개(제주시-동, 제주시-중, 제주시-서, 서귀포시-동, 서귀포시-중, 서귀포시-서)

# %% [markdown]
# ### * resd=제주

# %%
def test(x) :
  if x in ['성산읍','표선면','남원읍'] : return '서귀포시_동'
  elif x in ['대륜동','대천동','동홍동','서홍동','송산동','영천동','예래동','정방동','중문동','중앙동','천지동','효돈동'] : return '서귀포시_중'
  elif x in ['대정읍','안덕면'] : return '서귀포시_서'
  elif x in ['구좌읍','조천읍'] : return '제주시_동'
  elif x in ['건입동','노형동','도두동','봉개동','삼도2동','삼도1동','삼양동','아라동','연동','오라동','외도동','용담2동','용담1동','이도2동','이도1동','이호동','일도2동','일도1동','화북동'] : return '제주시_중'
  elif x in ['애월읍','한림읍','한경면'] : return '제주시_서'

df_jeju2['region'] = df_jeju2['emd_nm'].apply(test)

# %%
df_jeju2
# Out:
#          base_date time_2  city  ...  work_pop_cnt visit_pop_cnt  region
# 0       2018-01-01      낮  서귀포시  ...       13.0664      270.6256  서귀포시_서
# 1       2018-01-01      낮  서귀포시  ...       15.1443      194.9233  서귀포시_동
# 2       2018-01-01      낮  서귀포시  ...       50.8318      417.2296  서귀포시_동
# 3       2018-01-01      낮  서귀포시  ...      163.9979      320.0297  서귀포시_서
# 4       2018-01-01      낮  서귀포시  ...        8.7340      112.4051  서귀포시_동
# ...            ...    ...   ...  ...           ...           ...     ...
# 109813  2021-06-30      밤   제주시  ...      195.5954      579.1678   제주시_중
# 109814  2021-06-30      밤   제주시  ...      163.1943      700.2975   제주시_중
# 109815  2021-06-30      밤   제주시  ...       21.9826       72.1834   제주시_중
# 109816  2021-06-30      밤   제주시  ...       23.5358      128.9502   제주시_중
# 109817  2021-06-30      밤   제주시  ...       15.7211       67.8271   제주시_중
#
# [109818 rows x 9 columns]

# %%
df_jeju2.columns
# Out:
# Index(['base_date', 'time_2', 'city', 'emd_cd', 'emd_nm', 'resd_pop_cnt',
#        'work_pop_cnt', 'visit_pop_cnt', 'region'],
#       dtype='object')

# %% [markdown]
# ### * resd=그외

# %%
def test(x) :
  if x in ['성산읍','표선면','남원읍'] : return '서귀포시_동'
  elif x in ['대륜동','대천동','동홍동','서홍동','송산동','영천동','예래동','정방동','중문동','중앙동','천지동','효돈동'] : return '서귀포시_중'
  elif x in ['대정읍','안덕면'] : return '서귀포시_서'
  elif x in ['구좌읍','조천읍'] : return '제주시_동'
  elif x in ['건입동','노형동','도두동','봉개동','삼도2동','삼도1동','삼양동','아라동','연동','오라동','외도동','용담2동','용담1동','이도2동','이도1동','이호동','일도2동','일도1동','화북동'] : return '제주시_중'
  elif x in ['애월읍','한림읍','한경면'] : return '제주시_서'

df_etc2['region'] = df_etc2['emd_nm'].apply(test)

# %%
df_etc2
# Out:
#          base_date time_2  city  ...  work_pop_cnt visit_pop_cnt  region
# 0       2018-01-01      낮  서귀포시  ...       35.5750      152.2208  서귀포시_서
# 1       2018-01-01      낮  서귀포시  ...       37.1352      131.6772  서귀포시_동
# 2       2018-01-01      낮  서귀포시  ...       29.1916      267.4784  서귀포시_동
# 3       2018-01-01      낮  서귀포시  ...       23.6567      203.9756  서귀포시_서
# 4       2018-01-01      낮  서귀포시  ...       28.3955      123.1803  서귀포시_동
# ...            ...    ...   ...  ...           ...           ...     ...
# 109797  2021-06-30      밤   제주시  ...       32.1340      904.5847   제주시_중
# 109798  2021-06-30      밤   제주시  ...       30.6144      541.0726   제주시_중
# 109799  2021-06-30      밤   제주시  ...        5.2404      108.9141   제주시_중
# 109800  2021-06-30      밤   제주시  ...        0.0000      129.6280   제주시_중
# 109801  2021-06-30      밤   제주시  ...        0.0000       98.5622   제주시_중
#
# [109802 rows x 9 columns]

# %%
df_etc2.columns
# Out:
# Index(['base_date', 'time_2', 'city', 'emd_cd', 'emd_nm', 'resd_pop_cnt',
#        'work_pop_cnt', 'visit_pop_cnt', 'region'],
#       dtype='object')

# %% [markdown]
# ## 4) 시간대 변수 생성

# %% [markdown]
# ### * resd=제주

# %%
data12 = df_jeju2[df_jeju2['time_2'] == '낮'].drop(['time_2'], axis = 1)
data24 = df_jeju2[df_jeju2['time_2'] == '밤'].drop(['time_2'], axis = 1)

# %%
data12.columns
# Out:
# Index(['base_date', 'city', 'emd_cd', 'emd_nm', 'resd_pop_cnt', 'work_pop_cnt',
#        'visit_pop_cnt', 'region'],
#       dtype='object')

# %%
data12.columns = ['base_date', 'city', 'emd_cd', 'emd_nm', 'f_l_j_resd_12', 'f_l_j_work_12', 'f_l_j_visit_12', 'region']
data24.columns = ['base_date', 'city', 'emd_cd', 'emd_nm', 'f_l_j_resd_24', 'f_l_j_work_24', 'f_l_j_visit_24', 'region']

# %%
mg_jeju = pd.merge(data12,data24, how='outer',on=['base_date', 'city', 'emd_cd', 'emd_nm', 'region'])
mg_jeju
# Out:
#         base_date  city    emd_cd  ... f_l_j_resd_24  f_l_j_work_24  f_l_j_visit_24
# 0      2018-01-01  서귀포시  50130250  ...     1129.0599        24.0387        226.4320
# 1      2018-01-01  서귀포시  50130253  ...      345.7900        15.2458         69.6760
# 2      2018-01-01  서귀포시  50130259  ...      587.2609        26.4585        273.7653
# 3      2018-01-01  서귀포시  50130310  ...      870.6209       125.2491        232.6036
# 4      2018-01-01  서귀포시  50130320  ...      378.4108         7.3327         73.9492
# ...           ...   ...       ...  ...           ...            ...             ...
# 54906  2021-06-30   제주시  50110660  ...     2017.5754       163.1943        700.2975
# 54907  2021-06-30   제주시  50110670  ...      188.3524        21.9826         72.1834
# 54908  2021-06-30   제주시  50110680  ...      150.9372        23.5358        128.9502
# 54909  2021-06-30   제주시  50110690  ...       77.3760        15.7211         67.8271
# 54910  2019-08-11   제주시  50110330  ...        7.2817         0.0000          0.0000
#
# [54911 rows x 11 columns]

# %% [markdown]
# ### * resd=그외

# %%
data12 = df_etc2[df_etc2['time_2'] == '낮'].drop(['time_2'], axis = 1)
data24 = df_etc2[df_etc2['time_2'] == '밤'].drop(['time_2'], axis = 1)

# %%
data12.columns
# Out:
# Index(['base_date', 'city', 'emd_cd', 'emd_nm', 'resd_pop_cnt', 'work_pop_cnt',
#        'visit_pop_cnt', 'region'],
#       dtype='object')

# %%
data12.columns = ['base_date', 'city', 'emd_cd', 'emd_nm', 'f_l_e_resd_12', 'f_l_e_work_12', 'f_l_e_visit_12', 'region']
data24.columns = ['base_date', 'city', 'emd_cd', 'emd_nm', 'f_l_e_resd_24', 'f_l_e_work_24', 'f_l_e_visit_24', 'region']

# %%
mg_etc = pd.merge(data12,data24, how='outer',on=['base_date', 'city', 'emd_cd', 'emd_nm', 'region'])
mg_etc
# Out:
#         base_date  city    emd_cd  ... f_l_e_resd_24  f_l_e_work_24  f_l_e_visit_24
# 0      2018-01-01  서귀포시  50130250  ...           0.0        29.8549        119.3026
# 1      2018-01-01  서귀포시  50130253  ...           0.0        54.7028         75.8742
# 2      2018-01-01  서귀포시  50130259  ...           0.0        29.5355        178.0462
# 3      2018-01-01  서귀포시  50130310  ...           0.0        46.3578        159.0939
# 4      2018-01-01  서귀포시  50130320  ...           0.0        36.7293         64.5151
# ...           ...   ...       ...  ...           ...            ...             ...
# 54904  2021-06-30   제주시  50110670  ...           0.0         5.2404        108.9141
# 54905  2021-06-30   제주시  50110680  ...           0.0         0.0000        129.6280
# 54906  2021-06-30   제주시  50110690  ...           0.0         0.0000         98.5622
# 54907  2019-09-22   제주시  50110330  ...           0.0         0.0000          6.4832
# 54908  2019-10-02   제주시  50110330  ...           0.0         0.0000         11.5811
#
# [54909 rows x 11 columns]

# %% [markdown]
# ## 5) 데이터 병합

# %%
final = pd.merge(mg_jeju,mg_etc, how='outer',on=['base_date', 'city', 'emd_cd', 'emd_nm', 'region'])
final
# Out:
#         base_date  city    emd_cd  ... f_l_e_resd_24  f_l_e_work_24  f_l_e_visit_24
# 0      2018-01-01  서귀포시  50130250  ...           0.0        29.8549        119.3026
# 1      2018-01-01  서귀포시  50130253  ...           0.0        54.7028         75.8742
# 2      2018-01-01  서귀포시  50130259  ...           0.0        29.5355        178.0462
# 3      2018-01-01  서귀포시  50130310  ...           0.0        46.3578        159.0939
# 4      2018-01-01  서귀포시  50130320  ...           0.0        36.7293         64.5151
# ...           ...   ...       ...  ...           ...            ...             ...
# 54906  2021-06-30   제주시  50110660  ...           0.0        30.6144        541.0726
# 54907  2021-06-30   제주시  50110670  ...           0.0         5.2404        108.9141
# 54908  2021-06-30   제주시  50110680  ...           0.0         0.0000        129.6280
# 54909  2021-06-30   제주시  50110690  ...           0.0         0.0000         98.5622
# 54910  2019-08-11   제주시  50110330  ...           0.0         0.0000          9.7672
#
# [54911 rows x 17 columns]

# %%
final.to_csv('/content/drive/MyDrive/21 세미프로젝트_2차 (1)/코드_현정/newdata3_장기체류_외국인_유동인구', encoding='cp949', index=False)

# %% [markdown]
# # 4. 데이터 분포 재확인

# %% [markdown]
# ## 1) 시간대별

# %% [markdown]
# ### (1) 2018년

# %%
test18 = data1[data1['base_date'].dt.year==2018]
test18 = test18.groupby(['time']).sum()
test18
# Out:
#              emd_cd  visit_pop_cnt  weekend
# time
# 1     4280252619584   3.136414e+06    24259
# 2     4280001687129   3.144621e+06    24264
# 3     4278749247184   3.147335e+06    24255
# 4     4280352982153   3.145563e+06    24243
# 5     4278348648676   3.142920e+06    24221
# 6     4272384711156   3.142866e+06    24179
# 7     4265869780260   3.146713e+06    24139
# 8     4257449393596   3.123354e+06    24065
# 9     4272182606625   3.124430e+06    24175
# 10    4317892685798   3.154437e+06    24372
# 11    4349520344412   3.158312e+06    24522
# 12    4338947155038   3.140486e+06    24497
# 13    4306176662725   3.157991e+06    24293
# 14    4293348517840   3.143792e+06    24281
# 15    4298310862784   3.152091e+06    24313
# 16    4307479671541   3.137300e+06    24305
# 17    4356187809912   3.137019e+06    24561
# 18    4388457489081   3.140642e+06    24739
# 19    4394120423552   3.137860e+06    24791
# 20    4377980461144   3.138965e+06    24679
# 21    4366252782675   3.147156e+06    24597
# 22    4338939131194   3.168990e+06    24455
# 23    4309169754947   3.140302e+06    24317
# 24    4282155933074   3.107746e+06    24148

# %%
test18_2 = df1[df1['base_date'].dt.year==2018]
test18_2 = test18_2.groupby(['time_2']).sum()
test18_2
# Out:
#         visit_pop_cnt  week_date  weekend     year  month    day
# time_2
# 새벽       1.196248e+06      13104     1248  8838840  28584  68856
# 오전       1.271504e+06      13104     1248  8838840  28584  68856
# 오후       1.264990e+06      13104     1248  8838840  28584  68856
# 저녁       1.204489e+06      13104     1248  8838840  28584  68856

# %%
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (16, 8)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.arange(1, 25)
y1 = np.array(test18['visit_pop_cnt'])

x_2 = test18_2.index
y1_2 = np.array(test18_2['visit_pop_cnt'])


# 3. 그래프 그리기
fig = plt.figure()
ax1 = plt.subplot(1,2,1)
ax4 = plt.subplot(1,2,2)

## 1) time 변수
ax1.plot(x, y1, color='green', markersize=7, linewidth=5, alpha=0.7, label='resd')
ax1.set_ylim(0, 8000000)
ax1.set_xlabel('time')
ax1.set_ylabel('pop_cnt')
ax1.tick_params(axis='both', direction='in')

ax1.legend(loc=(0, 0.5), ncol=1)

plt.title('year 2018 visit by time')

## 2)time_2 변수
ax4.plot(x_2, y1_2, color='green', markersize=7, linewidth=5, alpha=0.7, label='resd')
ax4.set_ylim(0, 2000000)
ax4.set_xlabel('time')
ax4.set_ylabel('pop_cnt')
ax4.tick_params(axis='both', direction='in')

ax4.legend(loc=(0, 0.5), ncol=1)


plt.title('year 2018 visit by time')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48317 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50724 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45377 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48317 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50724 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45377 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 2) 주말/비주말

# %% [markdown]
# ### (3) 2020년

# %%
week20_2 = df1[df1['base_date'].dt.year==2020]
week20_2 = week20_2.groupby(['location', 'days']).mean()

# %%
week20_2 = week20_2.reset_index()
week20_2
# Out:
#    location       days  visit_pop_cnt  ...    year     month        day
# 0    서귀포시 동     Friday      31.493710  ...  2020.0  6.442308  15.942308
# 1    서귀포시 동     Monday      29.414902  ...  2020.0  6.538462  16.000000
# 2    서귀포시 동   Saturday      29.174367  ...  2020.0  6.480769  15.750000
# 3    서귀포시 동     Sunday      30.740741  ...  2020.0  6.519231  15.596154
# 4    서귀포시 동   Thursday      30.988157  ...  2020.0  6.528302  15.811321
# 5    서귀포시 동    Tuesday      30.949645  ...  2020.0  6.576923  15.826923
# 6    서귀포시 동  Wednesday      30.082063  ...  2020.0  6.509434  15.377358
# 7    서귀포시 서     Friday      23.526470  ...  2020.0  6.442308  15.942308
# 8    서귀포시 서     Monday      19.567507  ...  2020.0  6.530120  15.992771
# 9    서귀포시 서   Saturday      23.108749  ...  2020.0  6.480769  15.750000
# 10   서귀포시 서     Sunday      22.346827  ...  2020.0  6.519231  15.596154
# 11   서귀포시 서   Thursday      21.259177  ...  2020.0  6.528302  15.811321
# 12   서귀포시 서    Tuesday      18.786625  ...  2020.0  6.576923  15.826923
# 13   서귀포시 서  Wednesday      23.537462  ...  2020.0  6.509434  15.377358
# 14   서귀포시 중     Friday      62.259437  ...  2020.0  6.442308  15.942308
# 15   서귀포시 중     Monday      52.911078  ...  2020.0  6.538462  16.000000
# 16   서귀포시 중   Saturday      60.362155  ...  2020.0  6.480769  15.750000
# 17   서귀포시 중     Sunday      52.740500  ...  2020.0  6.519231  15.596154
# 18   서귀포시 중   Thursday      58.192933  ...  2020.0  6.528302  15.811321
# 19   서귀포시 중    Tuesday      56.696081  ...  2020.0  6.576923  15.826923
# 20   서귀포시 중  Wednesday      63.380685  ...  2020.0  6.509434  15.377358
# 21    제주시 동     Friday      13.251277  ...  2020.0  6.442308  15.942308
# 22    제주시 동     Monday      12.252444  ...  2020.0  6.538462  16.000000
# 23    제주시 동   Saturday      12.981283  ...  2020.0  6.480769  15.750000
# 24    제주시 동     Sunday      13.613529  ...  2020.0  6.497585  15.666667
# 25    제주시 동   Thursday      13.853291  ...  2020.0  6.528302  15.811321
# 26    제주시 동    Tuesday      12.940763  ...  2020.0  6.576923  15.826923
# 27    제주시 동  Wednesday      14.608908  ...  2020.0  6.509434  15.377358
# 28    제주시 서     Friday      54.865212  ...  2020.0  6.442308  15.942308
# 29    제주시 서     Monday      56.721189  ...  2020.0  6.538462  16.000000
# 30    제주시 서   Saturday      55.072461  ...  2020.0  6.480769  15.750000
# 31    제주시 서     Sunday      54.901090  ...  2020.0  6.519231  15.596154
# 32    제주시 서   Thursday      56.848524  ...  2020.0  6.528302  15.811321
# 33    제주시 서    Tuesday      56.584533  ...  2020.0  6.576923  15.826923
# 34    제주시 서  Wednesday      62.625715  ...  2020.0  6.509434  15.377358
# 35    제주시 중     Friday     125.870040  ...  2020.0  6.442308  15.942308
# 36    제주시 중     Monday     119.916877  ...  2020.0  6.538462  16.000000
# 37    제주시 중   Saturday     125.986457  ...  2020.0  6.480769  15.750000
# 38    제주시 중     Sunday     123.625279  ...  2020.0  6.519231  15.596154
# 39    제주시 중   Thursday     124.270382  ...  2020.0  6.528302  15.811321
# 40    제주시 중    Tuesday     114.973288  ...  2020.0  6.576923  15.826923
# 41    제주시 중  Wednesday     129.991729  ...  2020.0  6.509434  15.377358
#
# [42 rows x 8 columns]

# %%
# visit_pop_cnt
plt.rcParams['figure.figsize'] = [18, 12]

max_val = np.ceil(max(week20_2['visit_pop_cnt']))

for i, grp in enumerate(week20_2['location'].unique()):
    week20_2_i = week20_2[week20_2['location'] == grp]
    plt.subplot(2, 3, i+1)
    plt.bar(week20_2_i['days'], week20_2_i['visit_pop_cnt'], color='blue', alpha=0.5)
    plt.title('Group: %s' %grp, fontsize=18)
    plt.xlabel('X variable', fontsize=14)
    plt.ylabel('Value', fontsize=14)
    # plt.xticks(fontsize=12)
    # plt.yticks(fontsize=12)
    # set fixed y axis scale
    plt.ylim(0, max_val)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44480 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### (4) 2021년

# %%
week21_2 = df1[df1['base_date'].dt.year==2021]
week21_2 = week21_2.groupby(['location', 'days']).mean()

# %%
week21_2 = week21_2.reset_index()
week21_2
# Out:
#    location       days  resd_pop_cnt  ...    year     month        day
# 0    서귀포시 동     Friday    153.754092  ...  2021.0  3.423077  15.653846
# 1    서귀포시 동     Monday    153.500862  ...  2021.0  3.538462  15.230769
# 2    서귀포시 동   Saturday    155.812778  ...  2021.0  3.461538  15.500000
# 3    서귀포시 동     Sunday    151.813925  ...  2021.0  3.461538  16.500000
# 4    서귀포시 동   Thursday    152.696868  ...  2021.0  3.520000  15.240000
# 5    서귀포시 동    Tuesday    152.495404  ...  2021.0  3.576923  15.038462
# 6    서귀포시 동  Wednesday    151.528050  ...  2021.0  3.576923  16.038462
# 7    서귀포시 서     Friday    392.998103  ...  2021.0  3.423077  15.653846
# 8    서귀포시 서     Monday    390.741830  ...  2021.0  3.538462  15.230769
# 9    서귀포시 서   Saturday    378.544726  ...  2021.0  3.461538  15.500000
# 10   서귀포시 서     Sunday    379.203862  ...  2021.0  3.461538  16.500000
# 11   서귀포시 서   Thursday    396.168631  ...  2021.0  3.520000  15.240000
# 12   서귀포시 서    Tuesday    389.454848  ...  2021.0  3.576923  15.038462
# 13   서귀포시 서  Wednesday    389.810701  ...  2021.0  3.576923  16.038462
# 14   서귀포시 중     Friday    174.402051  ...  2021.0  3.423077  15.653846
# 15   서귀포시 중     Monday    168.668052  ...  2021.0  3.538462  15.230769
# 16   서귀포시 중   Saturday    171.363115  ...  2021.0  3.461538  15.500000
# 17   서귀포시 중     Sunday    170.323498  ...  2021.0  3.461538  16.500000
# 18   서귀포시 중   Thursday    172.492223  ...  2021.0  3.520000  15.240000
# 19   서귀포시 중    Tuesday    169.768905  ...  2021.0  3.576923  15.038462
# 20   서귀포시 중  Wednesday    169.612863  ...  2021.0  3.576923  16.038462
# 21    제주시 동     Friday    162.173619  ...  2021.0  3.423077  15.653846
# 22    제주시 동     Monday    157.561025  ...  2021.0  3.538462  15.230769
# 23    제주시 동   Saturday    163.040176  ...  2021.0  3.461538  15.500000
# 24    제주시 동     Sunday    158.232329  ...  2021.0  3.461538  16.500000
# 25    제주시 동   Thursday    159.792726  ...  2021.0  3.520000  15.240000
# 26    제주시 동    Tuesday    157.076766  ...  2021.0  3.576923  15.038462
# 27    제주시 동  Wednesday    156.675268  ...  2021.0  3.576923  16.038462
# 28    제주시 서     Friday    391.151763  ...  2021.0  3.423077  15.653846
# 29    제주시 서     Monday    376.106750  ...  2021.0  3.538462  15.230769
# 30    제주시 서   Saturday    392.594833  ...  2021.0  3.461538  15.500000
# 31    제주시 서     Sunday    379.715256  ...  2021.0  3.461538  16.500000
# 32    제주시 서   Thursday    378.112079  ...  2021.0  3.520000  15.240000
# 33    제주시 서    Tuesday    380.802289  ...  2021.0  3.576923  15.038462
# 34    제주시 서  Wednesday    372.068269  ...  2021.0  3.576923  16.038462
# 35    제주시 중     Friday   1044.900442  ...  2021.0  3.423077  15.653846
# 36    제주시 중     Monday   1047.636367  ...  2021.0  3.538462  15.230769
# 37    제주시 중   Saturday   1042.743927  ...  2021.0  3.461538  15.500000
# 38    제주시 중     Sunday   1049.848123  ...  2021.0  3.461538  16.500000
# 39    제주시 중   Thursday   1050.219936  ...  2021.0  3.520000  15.240000
# 40    제주시 중    Tuesday   1047.044966  ...  2021.0  3.576923  15.038462
# 41    제주시 중  Wednesday   1036.693653  ...  2021.0  3.576923  16.038462
#
# [42 rows x 10 columns]

# %%
week21_2['location'].unique()
# Out:
# array(['서귀포시 동', '서귀포시 서', '서귀포시 중', '제주시 동', '제주시 서', '제주시 중'],
#       dtype=object)

# %%
plt.rcParams['figure.figsize'] = [18, 12]

max_val = np.ceil(max(week21_2['resd_pop_cnt']))

for i, grp in enumerate(week21_2['location'].unique()):
    week21_2_i = week21_2[week21_2['location'] == grp]
    plt.subplot(2, 3, i+1)
    plt.bar(week21_2_i['days'], week21_2_i['resd_pop_cnt'], color='blue', alpha=0.5)
    plt.title('Group: %s' %grp, fontsize=18)
    plt.xlabel('X variable', fontsize=14)
    plt.ylabel('Value', fontsize=14)
    # plt.xticks(fontsize=12)
    # plt.yticks(fontsize=12)
    # set fixed y axis scale
    plt.ylim(0, max_val)
